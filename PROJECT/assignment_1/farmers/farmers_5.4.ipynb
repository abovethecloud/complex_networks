# %%
import networkx as nx  # to work on the graph
import matplotlib.pyplot as plt
import dzcnapy_plotlib as dzcnapy

# %%
G = nx.Graph()

# %% [markdown]
# setting the parameters of the graph

# %%
n_farmers = 50
#friendship_radius_proportion = 2/5
#friendship_radius = n_farmers * friendship_radius_proportion
friendship_radius = 20

# %%
for i in range(0, n_farmers):
    attr = 'Farmer '+ str(i)
    G.add_node(i, name= attr)
    min = i-friendship_radius if (i-friendship_radius) >= 0 else 0
    G.add_weighted_edges_from([(i, a, 1) for a in range(min, i)])
    if min > 0:
        G.add_weighted_edges_from([(i, b, -1) for b in range(0, min)])

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 10
# Number of edges: 45
# Average degree:   9.0000

# %%
print(G.edges(data = True))
# Out:
# [(0, 1, {'weight': 1}), (0, 2, {'weight': 1}), (0, 3, {'weight': 1}), (0, 4, {'weight': 1}), (0, 5, {'weight': -1}), (0, 6, {'weight': -1}), (0, 7, {'weight': -1}), (0, 8, {'weight': -1}), (0, 9, {'weight': -1}), (1, 2, {'weight': 1}), (1, 3, {'weight': 1}), (1, 4, {'weight': 1}), (1, 5, {'weight': 1}), (1, 6, {'weight': -1}), (1, 7, {'weight': -1}), (1, 8, {'weight': -1}), (1, 9, {'weight': -1}), (2, 3, {'weight': 1}), (2, 4, {'weight': 1}), (2, 5, {'weight': 1}), (2, 6, {'weight': 1}), (2, 7, {'weight': -1}), (2, 8, {'weight': -1}), (2, 9, {'weight': -1}), (3, 4, {'weight': 1}), (3, 5, {'weight': 1}), (3, 6, {'weight': 1}), (3, 7, {'weight': 1}), (3, 8, {'weight': -1}), (3, 9, {'weight': -1}), (4, 5, {'weight': 1}), (4, 6, {'weight': 1}), (4, 7, {'weight': 1}), (4, 8, {'weight': 1}), (4, 9, {'weight': -1}), (5, 6, {'weight': 1}), (5, 7, {'weight': 1}), (5, 8, {'weight': 1}), (5, 9, {'weight': 1}), (6, 7, {'weight': 1}), (6, 8, {'weight': 1}), (6, 9, {'weight': 1}), (7, 8, {'weight'
# ...

# %%
nx.draw_networkx(G)

# %%
nx.write_graphml(G, 'farmers.graphml', prettyprint = True)

# %%
pos = nx.spectral_layout(G)  # There are different types of layout
nx.draw_networkx(G, pos=pos, with_labels=True,**dzcnapy.medium_attrs)
# Out:
# /Users/claudio/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['Liberation Sans Narrow'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
